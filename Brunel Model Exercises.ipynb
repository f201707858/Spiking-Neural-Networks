# %%
# %matplotlib inline
from neurodynex.brunel_model import LIF_spiking_network
from neurodynex.tools import plot_tools
import brian2 as b2

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx = LIF_spiking_network.simulate_brunel_network(sim_time=250. * b2.ms)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx, t_min=0.*b2.ms)
# Out:
# INFO       width adjusted from 1. ms to 1.05 ms [brian2.monitors.ratemonitor.adjusted_width]
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49b6f53a50>)

# %% [markdown]
# # 11.1. Exercise: model parameters and threshold rate# QNO1

# %%
"""11.1.1"""
v_thres = LIF_spiking_network.FIRING_THRESHOLD/(LIF_spiking_network.N_POISSON_INPUT * LIF_spiking_network.SYNAPTIC_WEIGHT_W0*LIF_spiking_network.MEMBRANE_TIME_SCALE)
print(v_thres)
# Out:
# 10. Hz

# %%
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(poisson_input_rate=9*b2.Hz, sim_time=500.*b2.ms)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx, t_min=0.*b2.ms)
"""The definition of quiet is not clear.Assuming that the model is quiet means no activity ,then the model is not quiet from graph2 """
# Out:
# 'The definition of quiet is not clear.Assuming that the model is quiet means no activity ,then the model is not quiet from graph2 '

# %%
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)
# Out:
# 3

# %% [markdown]
# # 11.2. Exercise: Population activity

# %%
"""SR"""
POISSON_INPUT_RATE = 13. * b2.Hz
N_POISSON_INPUT = 1000
RELATIVE_INHIBITORY_STRENGTH_G = 2.5
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=0.*b2.ms)
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=950.*b2.ms)
# Out:
# 304
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49ad98b710>)

# %%
"""SI fast"""
POISSON_INPUT_RATE = 13. * b2.Hz
N_POISSON_INPUT = 1000
RELATIVE_INHIBITORY_STRENGTH_G =5
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=0.*b2.ms)
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=950.*b2.ms)
# Out:
# 21
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49bb013cd0>)

# %%
"""Quiscent"""
POISSON_INPUT_RATE = 5. * b2.Hz
N_POISSON_INPUT = 1000
RELATIVE_INHIBITORY_STRENGTH_G =5
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=0.*b2.ms)
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=950.*b2.ms)
# Out:
# 0
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49ac10a790>)

# %%
"""Asynchronous"""
POISSON_INPUT_RATE = 10. * b2.Hz
N_POISSON_INPUT = 1000
RELATIVE_INHIBITORY_STRENGTH_G =5
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=0.*b2.ms)
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=950.*b2.ms)
# Out:
# 9
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49ace81b50>)

# %%
"""SI slow"""
POISSON_INPUT_RATE = 10. * b2.Hz
N_POISSON_INPUT = 900
RELATIVE_INHIBITORY_STRENGTH_G =5
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=0.*b2.ms)
avgFiringRate = spike_monitor.num_spikes/spike_monitor.source.N
print(avgFiringRate)

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(N_Excit=6000,N_Inhib=1500,sim_time=1000.*b2.ms
                                ,w_external=0.1 * b2.mV,poisson_input_rate=POISSON_INPUT_RATE,N_extern=N_POISSON_INPUT,g=RELATIVE_INHIBITORY_STRENGTH_G)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx
                                 , t_min=950.*b2.ms)
# Out:
# 3
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f49ac778890>)

# %%
from neurodynex.tools import spike_tools
poisson_rate = 12 *b2.Hz
g = 2
CE = 6000
simtime = 150 *b2.ms

rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx = LIF_spiking_network.simulate_brunel_network(N_Excit=CE, poisson_input_rate=poisson_rate, g=g, sim_time=simtime)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx, t_min = 0*b2.ms)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor, spike_train_idx_list=monitored_spike_idx, t_min = simtime - 100*b2.ms)
spike_stats = spike_tools.get_spike_train_stats(spike_monitor, window_t_min= 100 *b2.ms)
plot_tools.plot_ISI_distribution(spike_stats, hist_nr_bins=100, xlim_max_ISI =50*b2.ms)

"""The reason for no isi graph is unclear """
# Out:
# 'The reason for no isi graph is unclear '

# %% [markdown]
# # 11.3. Exercise: Emergence of Synchronization

# %%
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(
    poisson_input_rate=14*b2.Hz,g= 2.5, sim_time=100.*b2.ms,N_Excit=6000,
        N_Inhib=1500)
plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor,
                                     spike_train_idx_list=monitored_spike_idx, t_min=0.*b2.ms,
                                     N_highlighted_spiketrains=3, avg_window_width=1. * b2.ms)

"""Model appears to be in SR state"""
# Out:
# (<Figure size 720x288 with 3 Axes>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe4c8f82790>)

# %%
import matplotlib.pyplot as plt
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(
    poisson_input_rate=14*b2.Hz,g= 2, sim_time=200.*b2.ms,N_Excit=6000,
        N_Inhib=1500,w0=0.*b2.mV, w_external = LIF_spiking_network.SYNAPTIC_WEIGHT_W0)

plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor,
                                     spike_train_idx_list=monitored_spike_idx, t_min=0.*b2.ms,
                                     N_highlighted_spiketrains=3, avg_window_width=1. * b2.ms)
"""It appears to move to state of AI as neurons in plot1 clear appear to spike at different times"""

# %%
import matplotlib.pyplot as plt
rate_monitor, spike_monitor, voltage_monitor, monitored_spike_idx =LIF_spiking_network.simulate_brunel_network(
    poisson_input_rate=14*b2.Hz,g= 2, sim_time=200.*b2.ms,N_Excit=6000,
        N_Inhib=1500,w0=0.*b2.mV, w_external = LIF_spiking_network.SYNAPTIC_WEIGHT_W0,random_vm_init=True )

plot_tools.plot_network_activity(rate_monitor, spike_monitor, voltage_monitor,
                                     spike_train_idx_list=monitored_spike_idx, t_min=0.*b2.ms,
                                     N_highlighted_spiketrains=3, avg_window_width=1. * b2.ms)
plt.show()
